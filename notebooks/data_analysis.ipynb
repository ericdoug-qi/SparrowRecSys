# %%
import pandas as pd
import os

# %%
data_root = "/Users/ericdoug/Documents/mydev/SparrowRecSys/src/main/resources/webroot/sampledata"
train_data_file = os.path.join(data_root, "trainingSamples.csv")
test_data_file = os.path.join(data_root, "testSamples.csv")

# %%
train_data = pd.read_csv(train_data_file, header=0)

# %%
train_data.describe
# Out:
# <bound method NDFrame.describe of        movieId  userId  rating   timestamp  label  releaseYear movieGenre1  \
# 0            1   15555     3.0   900953740      0         1995   Adventure
# 1            1   25912     3.5  1111631768      1         1995   Adventure
# 2            1   29912     3.0   866820360      0         1995   Adventure
# 3           10   17686     0.5  1195555011      0         1995      Action
# 4          104   20158     4.0  1155357691      1         1996      Comedy
# ...        ...     ...     ...         ...    ...          ...         ...
# 88822      968   26865     3.0   854092232      0         1968      Horror
# 88823      968    8507     2.0   974709061      0         1968      Horror
# 88824      969   16689     5.0   857854044      1         1951   Adventure
# 88825      969   26460     2.0  1250279576      0         1951   Adventure
# 88826      970    3033     2.0  1272394603      0         1953   Adventure
#
# ...

# %%
train_data.head(2)
# Out:
#    movieId  userId  rating   timestamp  label  releaseYear movieGenre1  \
# 0        1   15555     3.0   900953740      0         1995   Adventure
# 1        1   25912     3.5  1111631768      1         1995   Adventure
#
#   movieGenre2 movieGenre3  movieRatingCount  ...  userRatingCount  \
# 0   Animation    Children             10759  ...               92
# 1   Animation    Children             10759  ...               21
#
#    userAvgReleaseYear  userReleaseYearStddev  userAvgRating  userRatingStddev  \
# 0                1992                   8.98           3.86              0.74
# 1                1988                  14.09           3.48              1.28
#
#    userGenre1  userGenre2  userGenre3  userGenre4  userGenre5
# 0       Drama      Comedy    Thriller      Action       Crime
# 1      Action      Comedy     Romance   Adventure    Thriller
#
# [2 rows x 27 columns]

# %%
train_data[train_data.userId == 6]
# Out:
#        movieId  userId  rating  timestamp  label  releaseYear movieGenre1  \
# 33428      140       6     4.0  858275917      1         1996       Drama
# 33724      802       6     3.0  858275783      0         1996       Drama
#
#       movieGenre2 movieGenre3  movieRatingCount  ...  userRatingCount  \
# 33428     Romance         NaN              1103  ...               21
# 33724     Romance         NaN              2710  ...               18
#
#        userAvgReleaseYear  userReleaseYearStddev  userAvgRating  \
# 33428                1994                   4.11           3.90
# 33724                1994                   4.42           4.06
#
#        userRatingStddev  userGenre1  userGenre2  userGenre3  userGenre4  \
# 33428              0.94      Comedy     Romance   Adventure      Action
# 33724              0.94      Comedy     Romance   Adventure      Action
#
#        userGenre5
# 33428       Drama
# 33724       Drama
#
# [2 rows x 27 columns]
